# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 1: Load the data

# %%
train_values = pd.read_csv('train_values.csv')
train_labels = pd.read_csv('train_labels.csv')
train_values.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# ...

# %% [markdown]
# # Step 2: Analyse data

# %%
train_values.describe()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# count  2.606010e+05   260601.000000   260601.000000   260601.000000
# mean   5.256755e+05       13.900353      701.074685     6257.876148
# std    3.045450e+05        8.033617      412.710734     3646.369645
# min    4.000000e+00        0.000000        0.000000        0.000000
# 25%    2.611900e+05        7.000000      350.000000     3073.000000
# 50%    5.257570e+05       12.000000      702.000000     6270.000000
# 75%    7.897620e+05       21.000000     1050.000000     9412.000000
# max    1.052934e+06       30.000000     1427.000000    12567.000000
#
#        count_floors_pre_eq            age  area_percentage  height_percentage  \
# count        260601.000000  260601.000000    260601.000000      260601.000000
# mean              2.129723      26.535029         8.018051           5.434365
# std               0.727665      73.565937         4.392231           1.918418
# ...

# %%
train_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
# ...

# %% [markdown]
# # turn the data into purely numerical vales

# %%
df = pd.DataFrame({'A': ['a', 'b', 'a'], 'B': ['b', 'a', 'c'],
                  'C': [1, 2, 3]})

df
# Out:
#    A  B  C
# 0  a  b  1
# 1  b  a  2
# 2  a  c  3

# %%
pd.get_dummies(df)
# Out:
#    C    A_a    A_b    B_a    B_b    B_c
# 0  1   True  False  False   True  False
# 1  2  False   True   True  False  False
# 2  3   True  False  False  False   True

# %%
cat_columns = ["land_surface_condition",
"foundation_type",
"roof_type",
"ground_floor_type",
"other_floor_type",
"position",
"plan_configuration",
"legal_ownership_status"]

# %%
pd.get_dummies(train_values[cat_columns])
# Out:
#         land_surface_condition_n  land_surface_condition_o  \
# 0                          False                     False
# 1                          False                      True
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 260596                      True                     False
# 260597                     False                     False
# 260598                     False                     False
# 260599                     False                     False
# 260600                      True                     False
#
#         land_surface_condition_t  foundation_type_h  foundation_type_i  \
# 0                           True              False              False
# 1                          False              False              False
# ...

# %%
numerical_train_values = pd.get_dummies(data=train_values[cat_columns])
numerical_train_values
# Out:
#         land_surface_condition_n  land_surface_condition_o  \
# 0                          False                     False
# 1                          False                      True
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 260596                      True                     False
# 260597                     False                     False
# 260598                     False                     False
# 260599                     False                     False
# 260600                      True                     False
#
#         land_surface_condition_t  foundation_type_h  foundation_type_i  \
# 0                           True              False              False
# 1                          False              False              False
# ...

# %%
train_values_without_categories = train_values.drop(cat_columns, axis=1)
train_values_without_categories
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
df = pd.concat([train_values_without_categories,numerical_train_values], axis=1)
df
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
df['age'].describe()
# Out:
# count    260601.000000
# mean         26.535029
# std          73.565937
# min           0.000000
# 25%          10.000000
# 50%          15.000000
# 75%          30.000000
# max         995.000000
# Name: age, dtype: float64

# %%
age_cutoff = df['age'].quantile(0.99) # 
df.query("age < @age_cutoff")['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Let's try a decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
X = df.copy()
y = train_labels['damage_grade'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (208480, 69)
# (52121, 69)
# (208480,)
# (52121,)

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_hat = tree.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_hat)
print(f"The first run accuracy was {accuracy * 100}%")
# Out:
# The first run accuracy was 64.457704188331%

# %% [markdown]
# # Test with less data

# %%
X_train_mini = X_train.iloc[:1000]
X_test_mini = X_test.iloc[:1000]
y_train_mini = y_train.iloc[:1000]
y_test_mini = y_test.iloc[:1000]

# %%
tree.fit(X_train_mini, y_train_mini)
# Out:
# DecisionTreeClassifier()

# %%
y_test_mini_pred = tree.predict(X_test_mini)

# %%
y_test_mini
# Out:
# 111801    2
# 91817     2
# 251661    2
# 205479    2
# 22618     2
#          ..
# 196797    2
# 15413     1
# 237105    2
# 31701     3
# 166642    2
# Name: damage_grade, Length: 1000, dtype: int64

# %%
accuracy = accuracy_score(y_test_mini, y_test_mini_pred)

# %%
accuracy
# Out:
# 0.583

# %%
print(f"The first run accuracy was {accuracy * 100}%")
# Out:
# The first run accuracy was 58.3%
